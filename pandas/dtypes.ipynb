# %%
import numpy as np
import pandas as pd

# %%
dft = pd.DataFrame(
    {
        "A": np.random.rand(3),
        "B": 1,
        "C": "foo",
        "D": pd.Timestamp("20010102"),
        "E": pd.Series([1.0]*3).astype("float32"),
        "F": False,
        "G": pd.Series([1]*3,dtype="int8"),
    }
)
dft
# Out:
#           A  B    C          D    E      F  G
# 0  0.680111  1  foo 2001-01-02  1.0  False  1
# 1  0.102509  1  foo 2001-01-02  1.0  False  1
# 2  0.723268  1  foo 2001-01-02  1.0  False  1

# %%
import numpy as np
import pandas as pd

# %%
s = pd.Series(np.random.randn(5),index=["a","b","c","d","e"])
s
# Out:
# a   -2.150861
# b   -0.951821
# c    0.529415
# d    1.248473
# e   -0.087720
# dtype: float64

# %%
s.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
d = {"b":1, "a":0, "c":2}

# %%
pd.Series(d)
# Out:
# b    1
# a    0
# c    2
# dtype: int64

# %%
pd.Series(d,index=["b","c","d","a"])
# Out:
# b    1.0
# c    2.0
# d    NaN
# a    0.0
# dtype: float64

# %%
pd.Series(5.0,index=["a","b","c","d","e"])
# Out:
# a    5.0
# b    5.0
# c    5.0
# d    5.0
# e    5.0
# dtype: float64

# %%
s.iloc[0]
# Out:
# np.float64(-2.150861292260878)

# %%
s.iloc[:3]
# Out:
# a   -2.150861
# b   -0.951821
# c    0.529415
# dtype: float64

# %%
s[s > s.median()]
# Out:
# c    0.529415
# d    1.248473
# dtype: float64

# %%
s.iloc[[4,3,1]]
# Out:
# e   -0.087720
# d    1.248473
# b   -0.951821
# dtype: float64

# %%
np.exp(s)
# Out:
# a    0.116384
# b    0.386037
# c    1.697938
# d    3.485018
# e    0.916018
# dtype: float64

# %%
s.dtype
# Out:
# dtype('float64')

# %%
s.array
# Out:
# <NumpyExtensionArray>
# [  -2.150861292260878,  -0.9518212611899202,   0.5294146401459343,
#     1.248473107467041, -0.08771970912856197]
# Length: 5, dtype: float64

# %%
s.to_numpy()
# Out:
# array([-2.15086129, -0.95182126,  0.52941464,  1.24847311, -0.08771971])

# %%
print(s["a"])
print(s["e"])
# Out:
# -2.150861292260878
# -0.08771970912856197

# %%
s
# Out:
# a   -2.150861
# b   -0.951821
# c    0.529415
# d    1.248473
# e   -0.087720
# dtype: float64

# %%
print("e" in s)
print("f" in s)
# Out:
# True
# False

# %% [markdown]
# s["f"] will give error since the index doesn't exist. So use s.get("f") as it returns None when the index doesn't exist

# %%
print(s.get("f"))
print(s.get("f",np.nan))
# Out:
# None
# nan

# %% [markdown]
# panda series is just an extended form of numpy arrays. Most of the vectorized and other operations done on ndarrays thus will work on the panda series too.

# %%
s+s
# Out:
# a   -4.301723
# b   -1.903643
# c    1.058829
# d    2.496946
# e   -0.175439
# dtype: float64

# %%
s*3
# Out:
# a   -6.452584
# b   -2.855464
# c    1.588244
# d    3.745419
# e   -0.263159
# dtype: float64

# %%
np.exp(s)
# Out:
# a    0.116384
# b    0.386037
# c    1.697938
# d    3.485018
# e    0.916018
# dtype: float64

# %% [markdown]
# series aligns the data by itself based on index

# %%
s[1:] + s[:-1]
# Out:
# a         NaN
# b   -1.903643
# c    1.058829
# d    2.496946
# e         NaN
# dtype: float64

# %%
s = pd.Series(np.random.randn(5),name="something")
s
# Out:
# 0   -0.039473
# 1    2.132260
# 2   -1.002877
# 3   -1.083403
# 4    0.688125
# Name: something, dtype: float64

# %%
s.name
# Out:
# 'something'

# %%
s2 = s.rename("different")
print(s2.name)
s2.name = "different2"
print(s2.name)
# Out:
# different
# different2

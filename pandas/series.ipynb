# %%
import numpy as np
import pandas as pd

# %%
s = pd.Series(np.random.randn(5),index=["a","b","c","d","e"])
s
# Out:
# a   -0.779687
# b   -0.270206
# c    1.158899
# d    0.596887
# e   -0.961662
# dtype: float64

# %%
s.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
d = {"b":1, "a":0, "c":2}

# %%
pd.Series(d)
# Out:
# b    1
# a    0
# c    2
# dtype: int64

# %%
pd.Series(d,index=["b","c","d","a"])
# Out:
# b    1.0
# c    2.0
# d    NaN
# a    0.0
# dtype: float64

# %%
pd.Series(5.0,index=["a","b","c","d","e"])
# Out:
# a    5.0
# b    5.0
# c    5.0
# d    5.0
# e    5.0
# dtype: float64

# %%
s.iloc[0]
# Out:
# np.float64(-0.7796873092497028)

# %%
s.iloc[:3]
# Out:
# a   -0.779687
# b   -0.270206
# c    1.158899
# dtype: float64

# %%
s[s > s.median()]
# Out:
# c    1.158899
# d    0.596887
# dtype: float64

# %%
s.iloc[[4,3,1]]
# Out:
# e   -0.961662
# d    0.596887
# b   -0.270206
# dtype: float64

# %%
np.exp(s)
# Out:
# a    0.458549
# b    0.763222
# c    3.186425
# d    1.816456
# e    0.382257
# dtype: float64

# %%
s.dtype
# Out:
# dtype('float64')

# %%
s.array
# Out:
# <NumpyExtensionArray>
# [np.float64(-0.7796873092497028), np.float64(-0.2702063026475145),
#    np.float64(1.158899448776323),  np.float64(0.5968873643415271),
#  np.float64(-0.9616621994696148)]
# Length: 5, dtype: float64

# %%
s.to_numpy()
# Out:
# array([-0.77968731, -0.2702063 ,  1.15889945,  0.59688736, -0.9616622 ])

# %%
print(s["a"])
print(s["e"])
# Out:
# -0.7796873092497028
# -0.9616621994696148

# %%
s
# Out:
# a   -0.779687
# b   -0.270206
# c    1.158899
# d    0.596887
# e   -0.961662
# dtype: float64

# %%
print("e" in s)
print("f" in s)
# Out:
# True
# False

# %% [markdown]
# s["f"] will give error since the index doesn't exist. So use s.get("f") as it returns None when the index doesn't exist

# %%
print(s.get("f"))
print(s.get("f",np.nan))
# Out:
# None
# nan

# %% [markdown]
# panda series is just an extended form of numpy arrays. Most of the vectorized and other operations done on ndarrays thus will work on the panda series too.

# %%
s+s
# Out:
# a   -1.559375
# b   -0.540413
# c    2.317799
# d    1.193775
# e   -1.923324
# dtype: float64

# %%
s*3
# Out:
# a   -2.339062
# b   -0.810619
# c    3.476698
# d    1.790662
# e   -2.884987
# dtype: float64

# %%
np.exp(s)
# Out:
# a    0.458549
# b    0.763222
# c    3.186425
# d    1.816456
# e    0.382257
# dtype: float64

# %% [markdown]
# series aligns the data by itself based on index

# %%
s[1:] + s[:-1]
# Out:
# a         NaN
# b   -0.540413
# c    2.317799
# d    1.193775
# e         NaN
# dtype: float64

# %%
s = pd.Series(np.random.randn(5),name="something")
s
# Out:
# 0    0.007108
# 1    0.339406
# 2   -2.234081
# 3    0.233649
# 4    0.320993
# Name: something, dtype: float64

# %%
s.name
# Out:
# 'something'

# %%
s.name = "try"
s.name
# Out:
# 'try'

# %%
s2 = s.rename("different")
print(s2.name)
s2.name = "different2"
print(s2.name)
print(s.name)
# Out:
# different
# different2
# try
